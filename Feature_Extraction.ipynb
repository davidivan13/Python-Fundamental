# %% [markdown]
# <a href="https://colab.research.google.com/github/davidivan13/Python-Fundamental/blob/main/Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
other_rooms = dataset["total_rooms"] - dataset["total_bedrooms"]
other_rooms
# Out:
# 0        4329.0
# 1        5749.0
# 2         546.0
# 3        1164.0
# 4        1128.0
#           ...
# 16995    1823.0
# 16996    1821.0
# 16997    2146.0
# 16998    2120.0
# 16999    1520.0
# Length: 17000, dtype: float64

# %%
kepadatan = dataset["population"].div(dataset["households"])
kepadatan
# Out:
# 0        2.150424
# 1        2.438445
# 2        2.846154
# 3        2.278761
# 4        2.381679
#            ...
# 16995    2.457995
# 16996    2.567742
# 16997    2.728070
# 16998    2.715481
# 16999    2.985185
# Length: 17000, dtype: float64

# %%
dataset["other_rooms"] = other_rooms
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  other_rooms
# 0          1015.0       472.0         1.4936             66900.0       4329.0
# 1          1129.0       463.0         1.8200             80100.0       5749.0
# 2           333.0       117.0         1.6509             85700.0        546.0
# 3           515.0       226.0         3.1917             73400.0       1164.0
# 4           624.0       262.0         1.9250             65500.0       1128.0
# ...           ...         ...            ...                 ...          ...
# 16995       907.0       369.0         2.3571            111400.0       1823.0
# 16996      1194.0       465.0         2.5179             79000.0       1821.0
# 16997      1244.0       456.0         3.0313            103600.0       2146.0
# 16998      1298.0       478.0         1.9797             85800.0       2120.0
# 16999       806.0       270.0         3.0147             94600.0       1520.0
#
# [17000 rows x 10 columns]

# %%
dataset = dataset.assign(kepadatan = kepadatan)
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  other_rooms  \
# 0          1015.0       472.0         1.4936             66900.0       4329.0
# 1          1129.0       463.0         1.8200             80100.0       5749.0
# 2           333.0       117.0         1.6509             85700.0        546.0
# 3           515.0       226.0         3.1917             73400.0       1164.0
# 4           624.0       262.0         1.9250             65500.0       1128.0
# ...           ...         ...            ...                 ...          ...
# 16995       907.0       369.0         2.3571            111400.0       1823.0
# 16996      1194.0       465.0         2.5179             79000.0       1821.0
# 16997      1244.0       456.0         3.0313            103600.0       2146.0
# 16998      1298.0       478.0         1.9797             85800.0       2120.0
# 16999       806.0       270.0         3.0147             94600.0       1520.0
#
#        kepadatan
# 0       2.150424
# 1       2.438445
# 2       2.846154
# 3       2.278761
# 4       2.381679
# ...          ...
# 16995   2.457995
# 16996   2.567742
# 16997   2.728070
# 16998   2.715481
# 16999   2.985185
#
# [17000 rows x 11 columns]

# %%
dataset.insert(2, "price_income_ratio", dataset["median_house_value"] / dataset["median_income"])
dataset
# Out:
#        longitude  latitude  price_income_ratio  housing_median_age  \
# 0        -114.31     34.19        44791.108731                15.0
# 1        -114.47     34.40        44010.989011                19.0
# 2        -114.56     33.69        51911.078806                17.0
# 3        -114.57     33.64        22997.148855                14.0
# 4        -114.57     33.57        34025.974026                20.0
# ...          ...       ...                 ...                 ...
# 16995    -124.26     40.58        47261.465360                52.0
# 16996    -124.27     40.69        31375.352476                36.0
# 16997    -124.30     41.84        34176.755847                17.0
# 16998    -124.30     41.80        43339.899985                19.0
# 16999    -124.35     40.54        31379.573424                52.0
#
#        total_rooms  total_bedrooms  population  households  median_income  \
# 0           5612.0          1283.0      1015.0       472.0         1.4936
# 1           7650.0          1901.0      1129.0       463.0         1.8200
# 2            720.0           174.0       333.0       117.0         1.6509
# 3           1501.0           337.0       515.0       226.0         3.1917
# 4           1454.0           326.0       624.0       262.0         1.9250
# ...            ...             ...         ...         ...            ...
# 16995       2217.0           394.0       907.0       369.0         2.3571
# 16996       2349.0           528.0      1194.0       465.0         2.5179
# 16997       2677.0           531.0      1244.0       456.0         3.0313
# 16998       2672.0           552.0      1298.0       478.0         1.9797
# 16999       1820.0           300.0       806.0       270.0         3.0147
#
#        median_house_value  other_rooms  kepadatan
# 0                 66900.0       4329.0   2.150424
# 1                 80100.0       5749.0   2.438445
# 2                 85700.0        546.0   2.846154
# 3                 73400.0       1164.0   2.278761
# 4                 65500.0       1128.0   2.381679
# ...                   ...          ...        ...
# 16995            111400.0       1823.0   2.457995
# 16996             79000.0       1821.0   2.567742
# 16997            103600.0       2146.0   2.728070
# 16998             85800.0       2120.0   2.715481
# 16999             94600.0       1520.0   2.985185
#
# [17000 rows x 12 columns]

# %%
kepadatan_ruang = dataset["total_rooms"] / dataset["households"]

# %%
dataset.assign(kepadatan_ruang_kuadrat = kepadatan_ruang.pow(2))
# Out:
#        longitude  latitude  price_income_ratio  housing_median_age  \
# 0        -114.31     34.19        44791.108731                15.0
# 1        -114.47     34.40        44010.989011                19.0
# 2        -114.56     33.69        51911.078806                17.0
# 3        -114.57     33.64        22997.148855                14.0
# 4        -114.57     33.57        34025.974026                20.0
# ...          ...       ...                 ...                 ...
# 16995    -124.26     40.58        47261.465360                52.0
# 16996    -124.27     40.69        31375.352476                36.0
# 16997    -124.30     41.84        34176.755847                17.0
# 16998    -124.30     41.80        43339.899985                19.0
# 16999    -124.35     40.54        31379.573424                52.0
#
#        total_rooms  total_bedrooms  population  households  median_income  \
# 0           5612.0          1283.0      1015.0       472.0         1.4936
# 1           7650.0          1901.0      1129.0       463.0         1.8200
# 2            720.0           174.0       333.0       117.0         1.6509
# 3           1501.0           337.0       515.0       226.0         3.1917
# 4           1454.0           326.0       624.0       262.0         1.9250
# ...            ...             ...         ...         ...            ...
# 16995       2217.0           394.0       907.0       369.0         2.3571
# 16996       2349.0           528.0      1194.0       465.0         2.5179
# 16997       2677.0           531.0      1244.0       456.0         3.0313
# 16998       2672.0           552.0      1298.0       478.0         1.9797
# 16999       1820.0           300.0       806.0       270.0         3.0147
#
#        median_house_value  other_rooms  kepadatan  kepadatan_ruang_kuadrat
# 0                 66900.0       4329.0   2.150424               141.368070
# 1                 80100.0       5749.0   2.438445               272.998894
# 2                 85700.0        546.0   2.846154                37.869822
# 3                 73400.0       1164.0   2.278761                44.110757
# 4                 65500.0       1128.0   2.381679                30.798264
# ...                   ...          ...        ...                      ...
# 16995            111400.0       1823.0   2.457995                36.097627
# 16996             79000.0       1821.0   2.567742                25.518793
# 16997            103600.0       2146.0   2.728070                34.464109
# 16998             85800.0       2120.0   2.715481                31.247632
# 16999             94600.0       1520.0   2.985185                45.437586
#
# [17000 rows x 13 columns]

# %%
import seaborn as sns

# %%
mpg_dataset = sns.load_dataset("mpg")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpg_dataset["origin"].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
mpg_dataset.loc[mpg_dataset["origin"] == "usa", "origin"] = "america"
mpg_dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year   origin                       name
# 0            70  america  chevrolet chevelle malibu
# 1            70  america          buick skylark 320
# 2            70  america         plymouth satellite
# 3            70  america              amc rebel sst
# 4            70  america                ford torino
# ..          ...      ...                        ...
# 393          82  america            ford mustang gl
# 394          82   europe                  vw pickup
# 395          82  america              dodge rampage
# 396          82  america                ford ranger
# 397          82  america                 chevy s-10
#
# [398 rows x 9 columns]

# %%
mpg_dataset.loc[mpg_dataset["origin"] == "usa", "new_origin"] = "america"
mpg_dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year   origin                       name new_origin
# 0            70  america  chevrolet chevelle malibu        NaN
# 1            70  america          buick skylark 320        NaN
# 2            70  america         plymouth satellite        NaN
# 3            70  america              amc rebel sst        NaN
# 4            70  america                ford torino        NaN
# ..          ...      ...                        ...        ...
# 393          82  america            ford mustang gl        NaN
# 394          82   europe                  vw pickup        NaN
# 395          82  america              dodge rampage        NaN
# 396          82  america                ford ranger        NaN
# 397          82  america                 chevy s-10        NaN
#
# [398 rows x 10 columns]

# %%
mpg_dataset["new_origin"] = mpg_dataset["origin"].replace("japan", "asia")
mpg_dataset.query("origin == 'asia'")
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name, new_origin]
# Index: []

# %%
mpg_dataset["new_origin"] = mpg_dataset["origin"].map({"america": "usa",
                                                      "asia" : "japan",
                                                      "europe" : "europe"
})
mpg_dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year   origin                       name new_origin
# 0            70  america  chevrolet chevelle malibu        usa
# 1            70  america          buick skylark 320        usa
# 2            70  america         plymouth satellite        usa
# 3            70  america              amc rebel sst        usa
# 4            70  america                ford torino        usa
# ..          ...      ...                        ...        ...
# 393          82  america            ford mustang gl        usa
# 394          82   europe                  vw pickup     europe
# 395          82  america              dodge rampage        usa
# 396          82  america                ford ranger        usa
# 397          82  america                 chevy s-10        usa
#
# [398 rows x 10 columns]

# %%
mpg_dataset = mpg_dataset.rename(columns = {"origin": "country"})
mpg_dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  country                       name new_origin
# 0            70  america  chevrolet chevelle malibu        usa
# 1            70  america          buick skylark 320        usa
# 2            70  america         plymouth satellite        usa
# 3            70  america              amc rebel sst        usa
# 4            70  america                ford torino        usa
# ..          ...      ...                        ...        ...
# 393          82  america            ford mustang gl        usa
# 394          82   europe                  vw pickup     europe
# 395          82  america              dodge rampage        usa
# 396          82  america                ford ranger        usa
# 397          82  america                 chevy s-10        usa
#
# [398 rows x 10 columns]

# %%
mpg_dataset = mpg_dataset.drop(columns = "name")
mpg_dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  country new_origin
# 0            70  america        usa
# 1            70  america        usa
# 2            70  america        usa
# 3            70  america        usa
# 4            70  america        usa
# ..          ...      ...        ...
# 393          82  america        usa
# 394          82   europe     europe
# 395          82  america        usa
# 396          82  america        usa
# 397          82  america        usa
#
# [398 rows x 9 columns]

# %%
mpg_dataset.drop(columns = "new_origin", inplace = True)

# %%
mpg_dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  country
# 0            70  america
# 1            70  america
# 2            70  america
# 3            70  america
# 4            70  america
# ..          ...      ...
# 393          82  america
# 394          82   europe
# 395          82  america
# 396          82  america
# 397          82  america
#
# [398 rows x 8 columns]
